# %%
text = """
Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
customer feedback analysis, automatic translation, and voice assistants.
 
In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
online forms, tweets, product comments, and support tickets. However, this text data is often messy.
For example, a customer may write: "I LOVE this product!!! Visit https://example.com/product123 #Amazing #AI".
Another user may write: "The service was not good... I waited 45 minutes and no one replied."
 
Before applying machine learning or deep learning models, we need to clean and prepare the text.
This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
stemming, lemmatization, and sometimes removing emojis or special characters.
 
Good preprocessing can improve the quality of NLP models. However, preprocessing should be done carefully.
For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
can contain useful information about topics, opinions, or trends.
 
Your task is to build a complete NLP preprocessing pipeline for this text.
You should clean the text step by step and observe how the output changes after each step.
"""
import re 

import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords


import spacy
nlp = spacy.load("en_core_web_sm")

clean_text = re.sub(r'http\S+', '', text)          # To remove URLs
clean_text = re.sub(r'#\w+', '', clean_text)       # To remove hashtags
clean_text = re.sub(r'[^A-Za-z\s]', ' ', clean_text)  # To remove punctuation/numbers/emojis
 
print("Step 1 - Cleaned Text:\n")
print(clean_text)

lower_text = clean_text.lower()
 
print("\nStep 2 - Lowercase:\n")
print(lower_text)


tokens = word_tokenize(lower_text)

print("\nStep 3 - Tokens:\n")
print(tokens)


stop_words = set(stopwords.words('english'))
 
filtered_tokens = [word for word in tokens if word not in stop_words]
 
print("\nStep 4 - After Stopword Removal:\n")
print(filtered_tokens)

doc = nlp(" ".join(filtered_tokens))
 
lemmatized_tokens = [token.lemma_ for token in doc]
 
print("\nStep 5 - Lemmatized Tokens:\n")
print(lemmatized_tokens)


final_text = " ".join(lemmatized_tokens)
 
print("\nFinal Preprocessed Text Output:\n")
print(final_text)
# Out:
# Step 1 - Cleaned Text:
#
#
# Natural Language Processing  also known as NLP  is one of the most important areas of Artificial Intelligence
# Today  companies use NLP in chatbots  search engines  recommendation systems  social media analytics
# customer feedback analysis  automatic translation  and voice assistants
#
# In       many organizations are collecting huge amounts of text data from websites  emails  reviews
# online forms  tweets  product comments  and support tickets  However  this text data is often messy
# For example  a customer may write   I LOVE this product    Visit
# Another user may write   The service was not good    I waited    minutes and no one replied
#
# Before applying machine learning or deep learning models  we need to clean and prepare the text
# This step is called text preprocessing  It may include converting text to lowercase  removing URLs
# removing punctuation  removing numbers  tokenizing sentences into words  removing stop words
# stemming  lemmatization  and sometimes removing emojis or special characters
#
# Good preprocessing can improve the quality of NLP models  However  preprocessing should be done carefully
# For example  removing the word  not  from the sentence  I am not happy  can change the meaning completely
# Similarly  removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics  opinions  or trends
#
# Your task is to build a complete NLP preprocessing pipeline for this text
# You should clean the text step by step and observe how the output changes after each step
#
#
# Step 2 - Lowercase:
#
#
# natural language processing  also known as nlp  is one of the most important areas of artificial intelligence
# today  companies use nlp in chatbots  search engines  recommendation systems  social media analytics
# customer feedback analysis  automatic translation  and voice assistants
#
# in       many organizations are collecting huge amounts of text data from websites  emails  reviews
# online forms  tweets  product comments  and support tickets  however  this text data is often messy
# for example  a customer may write   i love this product    visit
# another user may write   the service was not good    i waited    minutes and no one replied
#
# before applying machine learning or deep learning models  we need to clean and prepare the text
# this step is called text preprocessing  it may include converting text to lowercase  removing urls
# removing punctuation  removing numbers  tokenizing sentences into words  removing stop words
# stemming  lemmatization  and sometimes removing emojis or special characters
#
# good preprocessing can improve the quality of nlp models  however  preprocessing should be done carefully
# for example  removing the word  not  from the sentence  i am not happy  can change the meaning completely
# similarly  removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics  opinions  or trends
#
# your task is to build a complete nlp preprocessing pipeline for this text
# you should clean the text step by step and observe how the output changes after each step
#
#
# Step 3 - Tokens:
#
# ['natural', 'language', 'processing', 'also', 'known', 'as', 'nlp', 'is', 'one', 'of', 'the', 'most', 'important', 'areas', 'of', 'artificial', 'intelligence', 'today', 'companies', 'use', 'nlp', 'in', 'chatbots', 'search', 'engines', 'recommendation', 'systems', 'social', 'media', 'analytics', 'customer', 'feedback', 'analysis', 'automatic', 'translation', 'and', 'voice', 'assistants', 'in', 'many', 'organizations', 'are', 'collecting', 'huge', 'amounts', 'of', 'text', 'data', 'from', 'websites', 'emails', 'reviews', 'online', 'forms', 'tweets', 'product', 'comments', 'and', 'support', 'tickets', 'however', 'this', 'text', 'data', 'is', 'often', 'messy', 'for', 'example', 'a', 'customer', 'may', 'write', 'i', 'love', 'this', 'product', 'visit', 'another', 'user', 'may', 'write', 'the', 'service', 'was', 'not', 'good', 'i', 'waited', 'minutes', 'and', 'no', 'one', 'replied', 'before', 'applying', 'machine', 'learning', 'or', 'deep', 'learning', 'models', 'we', 'need', 'to', 'clean', 'and', 'prepare', 'the', 'text', 'this', 'step', 'is', 'called', 'text', 'preprocessing', 'it', 'may', 'include', 'converting', 'text', 'to', 'lowercase', 'removing', 'urls', 'removing', 'punctuation', 'removing', 'numbers', 'tokenizing', 'sentences', 'into', 'words', 'removing', 'stop', 'words', 'stemming', 'lemmatization', 'and', 'sometimes', 'removing', 'emojis', 'or', 'special', 'characters', 'good', 'preprocessing', 'can', 'improve', 'the', 'quality', 'of', 'nlp', 'models', 'however', 'preprocessing', 'should', 'be', 'done', 'carefully', 'for', 'example', 'removing', 'the', 'word', 'not', 'from', 'the', 'sentence', 'i', 'am', 'not', 'happy', 'can', 'change', 'the', 'meaning', 'completely', 'similarly', 'removing', 'hashtags', 'may', 'not', 'always', 'be', 'a', 'good', 'idea', 'in', 'social', 'media', 'analytics', 'because', 'hashtags', 'can', 'contain', 'useful', 'information', 'about', 'topics', 'opinions', 'or', 'trends', 'your', 'task', 'is', 'to', 'build', 'a', 'complete', 'nlp', 'preprocessing', 'pipeline', 'for', 'this', 'text', 'you', 'should', 'clean', 'the', 'text', 'step', 'by', 'step', 'and', 'observe', 'how', 'the', 'output', 'changes', 'after', 'each', 'step']
#
# Step 4 - After Stopword Removal:
#
# ['natural', 'language', 'processing', 'also', 'known', 'nlp', 'one', 'important', 'areas', 'artificial', 'intelligence', 'today', 'companies', 'use', 'nlp', 'chatbots', 'search', 'engines', 'recommendation', 'systems', 'social', 'media', 'analytics', 'customer', 'feedback', 'analysis', 'automatic', 'translation', 'voice', 'assistants', 'many', 'organizations', 'collecting', 'huge', 'amounts', 'text', 'data', 'websites', 'emails', 'reviews', 'online', 'forms', 'tweets', 'product', 'comments', 'support', 'tickets', 'however', 'text', 'data', 'often', 'messy', 'example', 'customer', 'may', 'write', 'love', 'product', 'visit', 'another', 'user', 'may', 'write', 'service', 'good', 'waited', 'minutes', 'one', 'replied', 'applying', 'machine', 'learning', 'deep', 'learning', 'models', 'need', 'clean', 'prepare', 'text', 'step', 'called', 'text', 'preprocessing', 'may', 'include', 'converting', 'text', 'lowercase', 'removing', 'urls', 'removing', 'punctuation', 'removing', 'numbers', 'tokenizing', 'sentences', 'words', 'removing', 'stop', 'words', 'stemming', 'lemmatization', 'sometimes', 'removing', 'emojis', 'special', 'characters', 'good', 'preprocessing', 'improve', 'quality', 'nlp', 'models', 'however', 'preprocessing', 'done', 'carefully', 'example', 'removing', 'word', 'sentence', 'happy', 'change', 'meaning', 'completely', 'similarly', 'removing', 'hashtags', 'may', 'always', 'good', 'idea', 'social', 'media', 'analytics', 'hashtags', 'contain', 'useful', 'information', 'topics', 'opinions', 'trends', 'task', 'build', 'complete', 'nlp', 'preprocessing', 'pipeline', 'text', 'clean', 'text', 'step', 'step', 'observe', 'output', 'changes', 'step']
#
# Step 5 - Lemmatized Tokens:
#
# ['natural', 'language', 'processing', 'also', 'know', 'nlp', 'one', 'important', 'area', 'artificial', 'intelligence', 'today', 'company', 'use', 'nlp', 'chatbot', 'search', 'engine', 'recommendation', 'system', 'social', 'media', 'analytic', 'customer', 'feedback', 'analysis', 'automatic', 'translation', 'voice', 'assistant', 'many', 'organization', 'collect', 'huge', 'amount', 'text', 'datum', 'website', 'email', 'review', 'online', 'form', 'tweet', 'product', 'comment', 'support', 'ticket', 'however', 'text', 'datum', 'often', 'messy', 'example', 'customer', 'may', 'write', 'love', 'product', 'visit', 'another', 'user', 'may', 'write', 'service', 'good', 'wait', 'minute', 'one', 'reply', 'apply', 'machine', 'learn', 'deep', 'learning', 'model', 'need', 'clean', 'prepare', 'text', 'step', 'call', 'text', 'preprocessing', 'may', 'include', 'convert', 'text', 'lowercase', 'remove', 'url', 'remove', 'punctuation', 'remove', 'number', 'tokenize', 'sentence', 'word', 'remove', 'stop', 'word', 'stem', 'lemmatization', 'sometimes', 'remove', 'emojis', 'special', 'character', 'good', 'preprocessing', 'improve', 'quality', 'nlp', 'model', 'however', 'preprocesse', 'do', 'carefully', 'example', 'remove', 'word', 'sentence', 'happy', 'change', 'mean', 'completely', 'similarly', 'remove', 'hashtag', 'may', 'always', 'good', 'idea', 'social', 'media', 'analytic', 'hashtag', 'contain', 'useful', 'information', 'topic', 'opinion', 'trend', 'task', 'build', 'complete', 'nlp', 'preprocessing', 'pipeline', 'text', 'clean', 'text', 'step', 'step', 'observe', 'output', 'change', 'step']
#
# Final Preprocessed Text Output:
#
# natural language processing also know nlp one important area artificial intelligence today company use nlp chatbot search engine recommendation system social media analytic customer feedback analysis automatic translation voice assistant many organization collect huge amount text datum website email review online form tweet product comment support ticket however text datum often messy example customer may write love product visit another user may write service good wait minute one reply apply machine learn deep learning model need clean prepare text step call text preprocessing may include convert text lowercase remove url remove punctuation remove number tokenize sentence word remove stop word stem lemmatization sometimes remove emojis special character good preprocessing improve quality nlp model however preprocesse do carefully example remove word sentence happy change mean completely similarly remove hashtag may always good idea social media analytic hashtag contain useful information topic opinion trend task build complete nlp preprocessing pipeline text clean text step step observe output change step
